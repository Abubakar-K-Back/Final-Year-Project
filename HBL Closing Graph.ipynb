# %% [markdown]
# # HBL  1 (optional)

# %%
import numpy as np #arrays

# %%
import pandas as pd #data analysis
import matplotlib.pyplot as plt# data visualization
# %matplotlib inline
import matplotlib.dates as mdates

# %%
import datetime as dt

# %%
import urllib.request, json
import os
import numpy as np
import tensorflow as tf # deeplearning library
from sklearn.preprocessing import MinMaxScaler #machine learning library
# Out:
# C:\Users\Abubakar\Anaconda3\envs\tfdeeplearning\lib\site-packages\tensorflow\python\framework\dtypes.py:458: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Abubakar\Anaconda3\envs\tfdeeplearning\lib\site-packages\tensorflow\python\framework\dtypes.py:459: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Abubakar\Anaconda3\envs\tfdeeplearning\lib\site-packages\tensorflow\python\framework\dtypes.py:460: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
df=pd.read_csv('C:/Users/Abubakar/Desktop/Desktop Docs/PSX/HBL.csv')# loading dataset HBL

# %%
df.head()
# Out:
#   Symbol         Date    Open    High     Low   Close   Volume
# 0    HBL  16-Jul-2007  350.00  375.00  350.00  355.00  2975400
# 1    HBL  17-Jul-2007  357.60  359.85  337.25  341.40  2420100
# 2    HBL  18-Jul-2007  334.50  336.95  324.35  324.35  2029100
# 3    HBL  19-Jul-2007  321.00  322.90  308.15  308.50  2176800
# 4    HBL  20-Jul-2007  305.05  319.00  305.00  317.30  2019600

# %%
dates=df['Date']

# %%
x = [dt.datetime.strptime(d,'%d-%b-%Y').date() for d in dates]
y=df['Close']

# %%
#visualize closing prices of hbl
from matplotlib.pyplot import figure
figure(num=None, figsize=(17,5 ), dpi=80, facecolor='w', edgecolor='k')
plt.plot(x,y)
plt.gcf().autofmt_xdate()
plt.xlabel('Dates from 16-JUL-2007 To 29-Aug-2019',fontsize=15)
plt.ylabel('Habib Bank Last 5 Years Closing Prices',fontsize=15)
figure(figsize=(10,1))
plt.gcf().autofmt_xdate()

# %%
Open_category=pd.cut(df.Open,bins=[50,80,110,140,170,200,230,260,290,320,350,380],labels=['A','B','C','D','E','F','G','H','I','J','K'])

# %%
#KNN Applied
for p in range(len(Open_category)):
    df.at[p,'Opening Category']=Open_category[p]
df.drop('Open',axis=1)
# Out:
#      Symbol         Date    High     Low   Close    Volume Opening Category
# 0       HBL  16-Jul-2007  375.00  350.00  355.00   2975400                J
# 1       HBL  17-Jul-2007  359.85  337.25  341.40   2420100                K
# 2       HBL  18-Jul-2007  336.95  324.35  324.35   2029100                J
# 3       HBL  19-Jul-2007  322.90  308.15  308.50   2176800                J
# 4       HBL  20-Jul-2007  319.00  305.00  317.30   2019600                I
# 5       HBL  23-Jul-2007  324.90  318.55  324.90   1149500                J
# 6       HBL  24-Jul-2007  325.50  317.00  320.00    982600                J
# 7       HBL  25-Jul-2007  320.95  316.95  318.25    680600                I
# 8       HBL  26-Jul-2007  319.70  309.00  310.70   1308400                I
# 9       HBL  27-Jul-2007  325.90  309.05  324.00   4079700                I
# 10      HBL  30-Jul-2007  322.45  309.50  310.60   2973700                J
# ...

# %%
Train_Data=[]
import math
Train_Data=df[0:math.ceil(len(Openings_X)*0.7)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8f69d95be85f> in <module>()
#       1 Train_Data=[]
#       2 import math
# ----> 3 Train_Data=df[0:math.ceil(len(Openings_X)*0.7)]
#
# NameError: name 'Openings_X' is not defined

# %%
#Test Data
#Test_Openings=Openings_X[len(Train_Openings):len(Openings_X)]
#len(Test_Openings)

# %%
#Y_Dataset=df.iloc[:, 3:7]

# %%
#Y_Dataset_train=Y_Dataset[0:math.ceil(len(Y_Dataset)*0.7)]
#len(Y_Dataset_train)

# %%
#Y_Dataset_test=Openings_X[len(Y_Dataset_train):len(Y_Dataset)]
#len(Y_Dataset_test)

# %%
df
# Out:
#      Symbol         Date    Open    High     Low   Close    Volume  \
# 0       HBL  16-Jul-2007  350.00  375.00  350.00  355.00   2975400
# 1       HBL  17-Jul-2007  357.60  359.85  337.25  341.40   2420100
# 2       HBL  18-Jul-2007  334.50  336.95  324.35  324.35   2029100
# 3       HBL  19-Jul-2007  321.00  322.90  308.15  308.50   2176800
# 4       HBL  20-Jul-2007  305.05  319.00  305.00  317.30   2019600
# 5       HBL  23-Jul-2007  322.00  324.90  318.55  324.90   1149500
# 6       HBL  24-Jul-2007  325.50  325.50  317.00  320.00    982600
# 7       HBL  25-Jul-2007  319.00  320.95  316.95  318.25    680600
# 8       HBL  26-Jul-2007  318.15  319.70  309.00  310.70   1308400
# 9       HBL  27-Jul-2007  311.00  325.90  309.05  324.00   4079700
# 10      HBL  30-Jul-2007  321.00  322.45  309.50  310.60   2973700
# 11      HBL  31-Jul-2007  308.95  315.95  308.00  314.00   2778300
# 12      HBL  01-Aug-2007  312.50  328.70  312.00  325.00   8911200
# ...

# %%
df.head()
# Out:
#   Symbol         Date    Open    High     Low   Close   Volume  \
# 0    HBL  16-Jul-2007  350.00  375.00  350.00  355.00  2975400
# 1    HBL  17-Jul-2007  357.60  359.85  337.25  341.40  2420100
# 2    HBL  18-Jul-2007  334.50  336.95  324.35  324.35  2029100
# 3    HBL  19-Jul-2007  321.00  322.90  308.15  308.50  2176800
# 4    HBL  20-Jul-2007  305.05  319.00  305.00  317.30  2019600
#
#   Opening Category
# 0                J
# 1                K
# 2                J
# 3                J
# 4                I

# %%
#Matplot lib used
plt.figure(figsize = (18,9))
plt.plot(range(df.shape[0]),(df['Low']+df['High'])/2.0)
plt.xticks(range(0,df.shape[0],500),df['Date'].loc[::500],rotation=45)
plt.xlabel('Date',fontsize=18)
plt.ylabel('Mid Price',fontsize=18)
plt.show()

# %%
high_prices = df.loc[:,'High'].as_matrix()#converting to matrix
low_prices = df.loc[:,'Low'].as_matrix()
mid_prices = (high_prices+low_prices)/2.0

# %%
train_data = mid_prices[:1100]
test_data = mid_prices[1100:]

# %%
#Normalizing values
scaler = MinMaxScaler()
train_data = train_data.reshape(-1,1)
test_data = test_data.reshape(-1,1)

# %%
smoothing_window_size = 500
for di in range(1,2700,smoothing_window_size):
    scaler.fit(train_data[di:di+smoothing_window_size,:])
    train_data[di:di+smoothing_window_size,:] = scaler.transform(train_data[di:di+smoothing_window_size,:])

# You normalize the last bit of remaining data
scaler.fit(train_data[di+smoothing_window_size:,:])
train_data[di+smoothing_window_size:,:] = scaler.transform(train_data[di+smoothing_window_size:,:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-b8f769e991fa> in <module>()
#       1 smoothing_window_size = 500
#       2 for di in range(1,2700,smoothing_window_size):
# ----> 3     scaler.fit(train_data[di:di+smoothing_window_size,:])
#       4     train_data[di:di+smoothing_window_size,:] = scaler.transform(train_data[di:di+smoothing_window_size,:])
#       5
#
# ~\Anaconda3\envs\tfdeeplearning\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     306         # Reset internal state before fitting
#     307         self._reset()
# --> 308         return self.partial_fit(X, y)
#     309
#     310     def partial_fit(self, X, y=None):
#
# ~\Anaconda3\envs\tfdeeplearning\lib\site-packages\sklearn\preprocessing\data.py in partial_fit(self, X, y)
#     332
#     333         X = check_array(X, copy=self.copy, warn_on_dtype=True,
# ...

# %%
train_data = train_data.reshape(-1)
test_data = scaler.transform(test_data).reshape(-1)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-25-8d018eb0945d> in <module>()
#       1 train_data = train_data.reshape(-1)
# ----> 2 test_data = scaler.transform(test_data).reshape(-1)
#       3
#
# ~\Anaconda3\envs\tfdeeplearning\lib\site-packages\sklearn\preprocessing\data.py in transform(self, X)
#     363             Input data that will be transformed.
#     364         """
# --> 365         check_is_fitted(self, 'scale_')
#     366
#     367         X = check_array(X, copy=self.copy, dtype=FLOAT_DTYPES)
#
# ~\Anaconda3\envs\tfdeeplearning\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     735
#     736     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 737         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     738
#     739
#
# ...

# %%
#Linear Regression
EMA = 0.0
gamma = 0.1
for ti in range(len(train_data)):
    EMA = gamma*train_data[ti] + (1-gamma)*EMA
    train_data[ti] = EMA

# Used for visualization and test purposes
all_mid_data = np.concatenate([train_data,test_data],axis=0)

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
plt.style.use('bmh')

# %%
df.head()
# Out:
#   Symbol         Date    Open    High     Low   Close   Volume  \
# 0    HBL  16-Jul-2007  350.00  375.00  350.00  355.00  2975400
# 1    HBL  17-Jul-2007  357.60  359.85  337.25  341.40  2420100
# 2    HBL  18-Jul-2007  334.50  336.95  324.35  324.35  2029100
# 3    HBL  19-Jul-2007  321.00  322.90  308.15  308.50  2176800
# 4    HBL  20-Jul-2007  305.05  319.00  305.00  317.30  2019600
#
#   Opening Category
# 0                J
# 1                K
# 2                J
# 3                J
# 4                I

# %%
df = df[['Close']]

# %%
#Create a variable to predict 'x' days out into the future
future_days = 25
#Create a new column (the target or dependent variable) shifted 'x' units/days up
df['Prediction'] = df[['Close']].shift(-future_days)
#print the data
df.tail(4)
# Out:
# C:\Users\Abubakar\Anaconda3\envs\tfdeeplearning\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#        Close  Prediction
# 2944  113.53         NaN
# 2945  113.25         NaN
# 2946  110.74         NaN
# 2947  109.57         NaN

# %%
X = np.array(df.drop(['Prediction'], 1))[:-future_days]
print(X)
# Out:
# [[355.  ]
#  [341.4 ]
#  [324.35]
#  ...
#  [118.34]
#  [118.57]
#  [121.07]]

# %%
y = np.array(df['Prediction'])[:-future_days]
print(y)
# Out:
# [305.   305.   305.   ... 113.25 110.74 109.57]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
#Create the decision tree regressor model
tree = DecisionTreeRegressor().fit(x_train, y_train)
#Create the linear regression model
lr = LinearRegression().fit(x_train, y_train)

# %%
#Get the feature data, 
#AKA all the rows from the original data set except the last 'x' days
x_future = df.drop(['Prediction'], 1)[:-future_days]
#Get the last 'x' rows
x_future = x_future.tail(future_days) 
#Convert the data set into a numpy array
x_future = np.array(x_future)
x_future
# Out:
# array([[122.92],
#        [122.03],
#        [122.95],
#        [122.31],
#        [120.28],
#        [119.81],
#        [116.62],
#        [114.37],
#        [113.26],
#        [115.17],
#        [117.34],
#        [120.24],
#        [120.82],
#        [118.75],
#        [115.38],
#        [115.48],
#        [116.22],
#        [118.3 ],
#        [118.89],
#        [118.98],
#        [120.42],
#        [121.61],
#        [118.34],
#        [118.57],
#        [121.07]])

# %%
#Show the model tree prediction
tree_prediction = tree.predict(x_future)
print( tree_prediction )
print()
#Show the model linear regression prediction
lr_prediction = lr.predict(x_future)
print(lr_prediction)
# Out:
# [121.92  119.83  120.96  120.25  122.11  116.69  120.28  120.    117.97
#  115.51  143.1   116.36  110.88  106.17  106.15  115.135 119.055 119.29
#  121.05  114.57  115.93  128.9   117.01  110.74  109.57 ]
#
# [124.58036561 123.76634284 124.60780458 124.02243989 122.16573629
#  121.7358591  118.81818202 116.76025931 115.74501744 117.49196516
#  119.47671728 122.129151   122.65963774 120.76634885 117.68403795
#  117.77550118 118.45232909 120.35476431 120.89439737 120.97671428
#  122.29378482 123.38219727 120.3913496  120.60171503 122.88829582]

# %%
#Visualize the data
predictions = tree_prediction
#Plot the data
valid =  df[X.shape[0]:]
valid['Predictions'] = predictions #Create a new column called 'Predictions' that will hold the predicted prices
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Days',fontsize=18)
plt.ylabel('Close Price PKR',fontsize=18)
plt.plot(df['Close'])
plt.plot(valid[['Close','Predictions']])
plt.legend(['Train', 'Val', 'Prediction' ], loc='lower right')
plt.show()
# Out:
# C:\Users\Abubakar\Anaconda3\envs\tfdeeplearning\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
#Visualize the data
predictions = lr_prediction
#Plot the data
valid =  df[X.shape[0]:]
valid['Predictions'] = predictions #Create a new column called 'Predictions' that will hold the predicted prices
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Days',fontsize=18)
plt.ylabel('Close Price PKR',fontsize=18)
plt.plot(df['Close'])
plt.plot(valid[['Close','Predictions']])
plt.legend(['Train', 'Val', 'Prediction' ], loc='lower right')
plt.show()
# Out:
# C:\Users\Abubakar\Anaconda3\envs\tfdeeplearning\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
dataset_train = pd.read_csv('C:/Users/Abubakar/Desktop/Desktop Docs/PSX/HBL.csv')
training_set = dataset_train.iloc[:, 1:2].values

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
